# %% [markdown]
# <a href="https://colab.research.google.com/github/AchalaVP/SMA/blob/main/SMA_CIE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Program 1
#
# Write a python program to implement page rank algorithm.

# %%
import numpy as np

def calculate_pagerank(adjacency_matrix, damping_factor=0.85, max_iterations=100, convergence_threshold=0.0001):
    num_pages = adjacency_matrix.shape[0]
    initial_rank = np.ones(num_pages) / num_pages
    rank = initial_rank.copy()

    for _ in range(max_iterations):
        prev_rank = rank.copy()
        rank = (damping_factor * np.dot(adjacency_matrix, rank)) + ((1 - damping_factor) / num_pages)

        if np.linalg.norm(rank - prev_rank) < convergence_threshold:
            break

    return rank

# Example usage
adjacency_matrix = np.array([[0, 1, 1],
                             [1, 0, 0],
                             [0, 1, 0]])

pagerank = calculate_pagerank(adjacency_matrix)
print(pagerank)
# Out:
# [131974.54619607  99624.63908054  75204.42870338]

# %% [markdown]
# Program 2
#
# Link Prediction is used to predict future possible links in a network. Link Prediction is the
# algorithm based on which Facebook recommends People you May Know, Amazon predicts items
# you’re likely going to be interested in and Zomato recommends food you’re likely going to order.
# Implement link prediction using jaccard co efficient.

# %%
def jaccard_coefficient(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1) + len(set2) - intersection
    return intersection / union

def link_prediction_jaccard(graph, node):
    neighbors = set(graph[node])
    scores = []

    for other_node in graph:
        if other_node != node:
            other_neighbors = set(graph[other_node])
            score = jaccard_coefficient(neighbors, other_neighbors)
            scores.append((other_node, score))

    scores.sort(key=lambda x: x[1], reverse=True)
    return scores

graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'C'],
    'C': ['A', 'B', 'D'],
    'D': ['A', 'C'],
    'E': ['F'],
    'F': ['E']
}

node = 'A'
predictions = link_prediction_jaccard(graph, node)

print(f"Link predictions for node {node}:")
for prediction, score in predictions:
    #The nodes with higher Jaccard coefficients are more likely to have a link with the specified node.
    print(f"Node: {prediction}, Jaccard coefficient: {score}")
# Out:
# Link predictions for node A:
# Node: C, Jaccard coefficient: 0.5
# Node: B, Jaccard coefficient: 0.25
# Node: D, Jaccard coefficient: 0.25
# Node: E, Jaccard coefficient: 0.0
# Node: F, Jaccard coefficient: 0.0

# %% [markdown]
# Program 3
#
# Implement link Prediction Recommendation Engines with Node2Vec.

# %%
pip install node2vec
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: node2vec in /usr/local/lib/python3.10/dist-packages (0.4.6)
# Requirement already satisfied: gensim<5.0.0,>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.3.1)
# Requirement already satisfied: joblib<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.2.0)
# Requirement already satisfied: networkx<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from node2vec) (2.8.8)
# Requirement already satisfied: numpy<2.0.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.22.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.55.1 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.65.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.1.2->node2vec) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.1.2->node2vec) (6.3.0)

# %%
import networkx as nx
from node2vec import Node2Vec

# Create a graph using NetworkX (you can use your own graph as well)
graph = nx.Graph()
graph.add_edges_from([('1', '2'), ('1', '3'), ('2', '3'), ('2', '4'), ('3', '4')])

# Generate node embeddings using Node2Vec
node2vec = Node2Vec(graph, dimensions=64, walk_length=30, num_walks=200, workers=4)
model = node2vec.fit(window=10, min_count=1, batch_words=4)

# Get the node embeddings
embeddings = {node: model.wv[str(node)] for node in graph.nodes()}

def link_prediction(embeddings, node1, node2):
    emb1 = embeddings[str(node1)]
    emb2 = embeddings[str(node2)]
    similarity = cosine_similarity([emb1], [emb2])
    return similarity[0][0]

def recommendation_engine(embeddings, node, top_k=5):
    scores = []
    for other_node in embeddings:
        if other_node != str(node):
            score = link_prediction(embeddings, node, other_node)
            scores.append((other_node, score))
    scores.sort(key=lambda x: x[1], reverse=True)
    return scores[:top_k]

# Example usage
node = '1'
recommendations = recommendation_engine(embeddings, node, top_k=3)
print(f"Recommendations for node {node}:")
for recommendation, score in recommendations:
    print(f"Node: {recommendation}, Similarity Score: {score}")
# Out:
# Computing transition probabilities:   0%|          | 0/4 [00:00<?, ?it/s]
# Recommendations for node 1:
# Node: 4, Similarity Score: 0.9594818353652954
# Node: 3, Similarity Score: 0.947777509689331
# Node: 2, Similarity Score: 0.9415410757064819

# %% [markdown]
# Program 4
#
# a. Given a webpage extract all hyperlinks from the web page

# %%
import requests
from bs4 import BeautifulSoup

def extract_hyperlinks(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    hyperlinks = []

    for link in soup.find_all('a'):
        href = link.get('href')
        if href:
            hyperlinks.append(href)

    return hyperlinks

# Example usage
webpage_url = 'https://en.wikipedia.org/wiki/E-commerce'
hyperlinks = extract_hyperlinks(webpage_url)
for hyperlink in hyperlinks:
    print(hyperlink)
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=E-commerce
# /w/index.php?title=Special:UserLogin&returnto=E-commerce
# /w/index.php?title=Special:CreateAccount&returnto=E-commerce
# /w/index.php?title=Special:UserLogin&returnto=E-commerce
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Defining_e-commerce
# #Forms
# #Governmental_regulation
# #Global_trends
# #Logistics
# #Impacts
# #Impact_on_markets_and_retailers
# #Impact_on_supply_chain_management
# #Impact_on_employment
# #Impact_on_customers
# #Impact_on_the_environment
# #Impact_on_traditional_retail
# #E-commerce_during_COVID-19
# #Business_application
# #Timeline
# #See_also
# #References
# #Further_reading
# #External_links
# https://af.wikipedia.org/wiki/E-handel
# https://ar.wikipedia.org/wiki/%D8%AA%D8%AC%D8%A7%D8%B1%D8%A9_%D8%A5%D9%84%D9%83%D8%AA%D8%B1%D9%88%D9%86%D9%8A%D8%A9
# https://az.wikipedia.org/wiki/Elektron_ticar%C9%99t
# https://azb.wikipedia.org/wiki/%D8%A7%D9%84%DA%A9%D8%AA%D8%B1%D9%88%D9%86%DB%8C%DA%A9_%D8%A2%D9%84%E2%80%8C%D9%88%D8%A6%D8%B1
# https://bn.wikipedia.org/wiki/%E0%A6%87-%E0%A6%AC%E0%A6%BE%E0%A6%A3%E0%A6%BF%E0%A6%9C%E0%A7%8D%E0%A6%AF
# https://bg.wikipedia.org/wiki/%D0%95%D0%BB%D0%B5%D0%BA%D1%82%D1%80%D0%BE%D0%BD%D0%BD%D0%B0_%D1%82%D1%8A%D1%80%D0%B3%D0%BE%D0%B2%D0%B8%D1%8F
# https://ca.wikipedia.org/wiki/Comer%C3%A7_electr%C3%B2nic
# https://cs.wikipedia.org/wiki/Elektronick%C3%A9_obchodov%C3%A1n%C3%AD
# https://da.wikipedia.org/wiki/Elektronisk_handel
# https://de.wikipedia.org/wiki/Elektronischer_Handel
# https://et.wikipedia.org/wiki/E-kaubandus
# https://el.wikipedia.org/wiki/%CE%97%CE%BB%CE%B5%CE%BA%CF%84%CF%81%CE%BF%CE%BD%CE%B9%CE%BA%CF%8C_%CE%B5%CE%BC%CF%80%CF%8C%CF%81%CE%B9%CE%BF
# /wiki/Online_retailing
# /wiki/Electronic_markets
# /wiki/Online_auction
# /wiki/Electronic_business
# #cite_note-2
# #cite_note-3
# /wiki/Online_shopping
# /wiki/Direct_selling
# /wiki/Web_sites
# /wiki/Mobile_apps
# /wiki/Conversational_commerce
# /wiki/Live_chat
# /wiki/Chatbot
# /wiki/Voice_assistants
# #cite_note-venturebeat.com-4
# /wiki/Online_marketplace
# /wiki/Business-to-consumer
# /wiki/Consumer-to-consumer
# /wiki/B2B_e-commerce
# #cite_note-5
# /wiki/Electronic_data_interchange
# /wiki/Customer
# /wiki/Email_marketing
# /wiki/Newsletter
# /wiki/Pretail
# #cite_note-6
# /wiki/B2B_e-commerce
# /wiki/Retail
# /wiki/Consumer-to-business
# /wiki/Customer_to_customer
# #cite_note-7
# /wiki/Data_integrity
# /wiki/Data_security
# /wiki/Mobile_commerce
# /wiki/T-Commerce
# #cite_note-8
# /wiki/California_Privacy_Rights_Act
# /wiki/Federal_Trade_Commission
# /wiki/Consumer_privacy
# /wiki/CAN-SPAM_Act_of_2003
# /wiki/Federal_Trade_Commission_Act
# #cite_note-9
# #cite_note-10
# /wiki/Controlled_Substances_Act
# /wiki/Online_pharmacy
# #cite_note-11
# #cite_note-http://www.uncitral.org/uncitral/en/uncitral_texts/electronic_commerce/1996Model.html-12
# /wiki/Australian_Competition_%26_Consumer_Commission
# #cite_note-13
# #cite_note-14
# #cite_note-15
# /wiki/European_Commission
# /wiki/European_Union_competition_law
# #cite_note-16
# /wiki/Financial_Services_Authority
# #cite_note-17
# /wiki/Payment_Services_Directive
# /wiki/Prudential_Regulation_Authority_(United_Kingdom)
# /wiki/Financial_Conduct_Authority
# #cite_note-18
# #cite_note-19
# /wiki/Information_Technology_Act_2000
# /wiki/E-commerce_in_India
# /wiki/Ministry_of_Industry_and_Information_Technology
# #cite_note-20
# #cite_note-21
# #cite_note-22
# #cite_note-23
# #cite_note-24
# #cite_note-25
# #cite_note-26
# #cite_note-27
# /wiki/Alibaba_Group
# #cite_note-28
# #cite_note-29
# #cite_note-30
# #cite_note-31
# #cite_note-32
# #cite_note-33
# #cite_note-34
# /wiki/Wikipedia:Citation_needed
# #cite_note-35
# /wiki/Wikipedia:Citation_needed
# #cite_note-36
# #cite_note-37
# #cite_note-38
# #cite_note-39
# #cite_note-40
# #cite_note-41
# #cite_note-42
# #cite_note-43
# #cite_note-44
# /wiki/Facebook_3D_Posts
# #cite_note-45
# #cite_note-46
# /wiki/File:Store_Closing_Flags.jpg
# /wiki/File:Store_Closing_Flags.jpg
# /wiki/Toys_%22R%22_Us
# #cite_note-47
# /wiki/Brick_and_mortar
# #cite_note-:0-48
# #cite_note-49
# /wiki/Adware
# /wiki/Spyware
# /wiki/Phishing
# /wiki/Hacker
# /wiki/Vandalism
# /wiki/Firewall_(computing)
# /wiki/Encryption_software
# /wiki/Wikipedia:Citation_needed
# /wiki/Supply_chain_management
# #cite_note-ideas.repec.org-50
# #cite_note-ideas.repec.org-50
# /wiki/SAP_ERP
# /wiki/Xero_(software)
# #cite_note-ideas.repec.org-50
# #cite_note-:2-51
# /wiki/Convenience
# /wiki/Bazaarvoice
# /wiki/Trustpilot
# /wiki/Yelp
# #cite_note-52
# #cite_note-53
# #cite_note-54
# /wiki/Tommy_Hilfiger
# #cite_note-55
# #cite_note-:0-48
# /wiki/Cardboard
# /wiki/Cardboard_box
# #cite_note-56
# /wiki/Invasive_species
# #cite_note-Newman-57
# /wiki/Weed
# /wiki/Crop_pest
# /wiki/Crop_disease
# #cite_note-Newman-57
# /wiki/Brushing_(e-commerce)
# #cite_note-Newman-57
# #cite_note-58
# #cite_note-59
# #cite_note-60
# /wiki/Economic_impact_of_the_COVID-19_pandemic
# #cite_note-61
# #cite_note-62
# #cite_note-63
# #cite_note-64
# /wiki/File:Automated_online_assistant.png
# /wiki/File:Automated_online_assistant.png
# /wiki/Automated_online_assistant
# /wiki/B2B_e-commerce
# /wiki/Business-to-business
# /wiki/Business-to-consumer
# /wiki/Conversational_commerce
# /wiki/Digital_wallet
# /wiki/Document_automation
# /wiki/Supply_chain
# /wiki/Electronic_ticket
# /wiki/Enterprise_content_management
# /wiki/Group_buying
# /wiki/Instant_messaging
# /wiki/Internet_security
# /wiki/Online_auction
# /wiki/Online_banking
# /wiki/Online_office_suite
# /wiki/Online_shopping
# /wiki/Track_and_trace
# /wiki/Online_transaction_processing
# /wiki/Pretail
# /wiki/Print_on_demand
# /wiki/Shopping_cart_software
# /wiki/Social_networking_service
# /wiki/Teleconference
# /wiki/Usenet_newsgroup
# /wiki/Virtual_assistant
# /wiki/Payment_system
# /wiki/ARPANET
# /wiki/Cannabis
# /wiki/Stanford_University_centers_and_institutes
# /wiki/Massachusetts_Institute_of_Technology
# /wiki/John_Markoff
# /wiki/What_the_Dormouse_Said
# #cite_note-65
# /wiki/Michael_Aldrich
# /wiki/Online_shopping
# #cite_note-66
# /wiki/B2B_e-commerce
# #cite_note-67
# /wiki/Minitel
# /wiki/Orange_S.A.
# /wiki/California_State_Assembly
# #cite_note-68
# /wiki/Kendall_Ross_Bean
# /wiki/San_Francisco_Bay_Area
# /wiki/Kaypro
# /wiki/DOS
# /wiki/Bulletin_board_system
# /wiki/Dot_matrix_printer
# /wiki/San_Francisco_Chronicle
# /wiki/Wire_transfer
# #cite_note-69
# #cite_note-70
# /wiki/Gateshead
# /wiki/Tesco
# #cite_note-71
# #cite_note-Finding_Mrs_Snowball-72
# /wiki/CompuServe
# #cite_note-73
# /wiki/Tim_Berners-Lee
# /wiki/WorldWideWeb
# /wiki/NeXTSTEP
# #cite_note-74
# /wiki/Book_Stacks_Unlimited
# #cite_note-75
# #cite_note-76
# /wiki/App_store
# /wiki/Electronic_AppWrapper
# #cite_note-PR-AW3-77
# /wiki/Netscape
# /wiki/Mozilla
# /wiki/Netscape_Navigator
# /wiki/Transport_Layer_Security
# /wiki/Ipswitch_IMail_Server
# /wiki/Ipswitch,_Inc.
# /wiki/OpenMarket
# /wiki/NetMarket
# #cite_note-78
# /wiki/National_Science_Foundation
# #cite_note-79
# /wiki/CompuServe
# /wiki/W_H_Smith
# /wiki/W_H_Smith
# /wiki/Tesco
# /wiki/Virgin_Megastores
# /wiki/Our_Price
# /wiki/GUS_(retailer)
# /wiki/Interflora
# /wiki/Dixons_Retail
# /wiki/PC_World_(retailer)
# /wiki/Amazon_(company)
# /wiki/Jeff_Bezos
# /wiki/EBay
# /wiki/Pierre_Omidyar
# /wiki/Online_auction
# #cite_note-Bunnell-80
# /wiki/NetRadio
# /wiki/Excalibur_BBS
# /wiki/Sysop
# /wiki/Australia
# /wiki/Electronic_stamp
# #cite_note-81
# /wiki/Alibaba_Group
# /wiki/Business.com
# /wiki/Napster
# /wiki/ATG_Stores
# #cite_note-:2-51
# /wiki/Dot-com_bust
# /wiki/EBay
# #cite_note-Bunnell-80
# /wiki/Alibaba_Group
# /wiki/EBay
# /wiki/PayPal
# #cite_note-82
# /wiki/Wayfair
# /wiki/NetShops
# /wiki/Amazon_(company)
# /wiki/DHgate.com
# /wiki/Yellow_pages
# #cite_note-83
# /wiki/Business.com
# /wiki/R.H._Donnelley
# #cite_note-84
# #cite_note-85
# /wiki/Alibaba_Group
# /wiki/Initial_public_offering
# /wiki/Amazon_(company)
# #cite_note-86
# #cite_note-87
# /wiki/Business-to-consumer
# #cite_note-88
# /wiki/Government_of_India
# /wiki/BHIM
# #cite_note-89
# #cite_note-90
# /wiki/Comparison_of_free_software_e-commerce_web_application_frameworks
# /wiki/Comparison_of_shopping_cart_software
# /wiki/Customer_intelligence
# /wiki/Digital_economy
# /wiki/E-commerce_credit_card_payment_system
# /wiki/Electronic_bill_payment
# /wiki/Electronic_money
# /wiki/Non-store_retailing
# /wiki/Payments_as_a_service
# /wiki/South_Dakota_v._Wayfair,_Inc.
# /wiki/Types_of_e-commerce
# /wiki/Timeline_of_e-commerce
# #cite_ref-1
# https://web.archive.org/web/20171126014712/https://www.statista.com/statistics/220177/b2c-e-commerce-sales-cagr-forecast-for-selected-countries/
# /wiki/Statista
# https://www.statista.com/statistics/220177/b2c-e-commerce-sales-cagr-forecast-for-selected-countries/
# #cite_ref-2
# https://www.ebscohost.com/uploads/imported/thisTopic-dbTopic-1074.pdf
# /w/index.php?title=Research_Starters:_Business&action=edit&redlink=1
# https://web.archive.org/web/20130718091809/http://www.ebscohost.com/uploads/imported/thisTopic-dbTopic-1074.pdf
# #cite_ref-3
# http://pubsonline.informs.org/doi/abs/10.1287/isre.12.2.135.9698
# /wiki/Doi_(identifier)
# https://doi.org/10.1287%2Fisre.12.2.135.9698
# /wiki/ISSN_(identifier)
# https://www.worldcat.org/issn/1047-7047
# https://web.archive.org/web/20220615223403/http://pubsonline.informs.org/doi/abs/10.1287/isre.12.2.135.9698
# #cite_ref-venturebeat.com_4-0
# https://venturebeat.com/2018/03/06/how-to-prepare-your-products-and-brand-for-conversational-commerce/
# /wiki/VentureBeat
# https://web.archive.org/web/20200929193753/https://venturebeat.com/2018/03/06/how-to-prepare-your-products-and-brand-for-conversational-commerce/
# #cite_ref-5
# https://www.mayple.com/ecommerce-marketing-strategy
# /w/index.php?title=Mayple&action=edit&redlink=1
# https://web.archive.org/web/20210428042004/https://www.mayple.com/ecommerce-marketing-strategy
# #cite_ref-6
# https://doi.org/10.3390%2Faxioms11030105
# /wiki/Doi_(identifier)
# https://doi.org/10.3390%2Faxioms11030105
# /wiki/ISSN_(identifier)
# https://www.worldcat.org/issn
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-609-60772-5
# /wiki/OCLC_(identifier)
# https://www.worldcat.org/oclc/1148801120
# /wiki/Template:Cite_book
# /wiki/Category:CS1_maint:_url-status
# /wiki/Wikipedia:Wikimedia_sister_projects
# https://en.wiktionary.org/wiki/e-commerce
# https://commons.wikimedia.org/wiki/Category:electronic_commerce
# https://en.wikinews.org/wiki/Category:Economy_and_business
# https://en.wikibooks.org/wiki/E-Commerce_and_E-Business
# https://en.wikiversity.org/wiki/Special:Search/E-commerce
# https://www.wikidata.org/wiki/Q484847
# https://web.archive.org/web/20170521010809/https://www.sba.gov/managing-business/running-business/using-technology/ecommerce-resources
# /wiki/Small_Business_Administration
# http://www.sba.gov/content/ecommerce-resources
# /wiki/Template:Computer_science
# /wiki/Template_talk:Computer_science
# https://en.wikipedia.org/w/index.php?title=Template:Computer_science&action=edit
# /wiki/Computer_science
# /wiki/ACM_Computing_Classification_System
# /wiki/Computer_hardware
# /wiki/Printed_circuit_board
# /wiki/Peripheral
# /wiki/Integrated_circuit
# /wiki/Very_Large_Scale_Integration
# /wiki/System_on_a_chip
# /wiki/Green_computing
# /wiki/Electronic_design_automation
# /wiki/Hardware_acceleration
# /wiki/File:Computer_Retro.svg
# /wiki/Computer_architecture
# /wiki/Embedded_system
# /wiki/Real-time_computing
# /wiki/Dependability
# /wiki/Computer_network
# /wiki/Network_architecture
# /wiki/Network_protocol
# /wiki/Networking_hardware
# /wiki/Network_scheduler
# /wiki/Network_performance
# /wiki/Network_service
# /wiki/Interpreter_(computing)
# /wiki/Middleware
# /wiki/Virtual_machine
# /wiki/Operating_system
# /wiki/Software_quality
# /wiki/Programming_language_theory
# /wiki/Programming_tool
# /wiki/Programming_paradigm
# /wiki/Programming_language
# /wiki/Compiler_construction
# /wiki/Domain-specific_language
# /wiki/Modeling_language
# /wiki/Software_framework
# /wiki/Integrated_development_environment
# /wiki/Software_configuration_management
# /wiki/Library_(computing)
# /wiki/Software_repository
# /wiki/Software_development
# /wiki/Control_variable_(programming)
# /wiki/Software_development_process
# /wiki/Requirements_analysis
# /wiki/Software_design
# /wiki/Software_construction
# /wiki/Software_deployment
# /wiki/Software_engineering
# /wiki/Software_maintenance
# /wiki/Programming_team
# /wiki/Open-source_software
# /wiki/Theory_of_computation
# /wiki/Model_of_computation
# /wiki/Formal_language
# /wiki/Automata_theory
# /wiki/Computability_theory
# /wiki/Computational_complexity_theory
# /wiki/Logic_in_computer_science
# /wiki/Semantics_(computer_science)
# /wiki/Algorithm
# /wiki/Algorithm_design
# /wiki/Analysis_of_algorithms
# /wiki/Algorithmic_efficiency
# /wiki/Randomized_algorithm
# /wiki/Computational_geometry
# /wiki/Discrete_mathematics
# /wiki/Probability
# /wiki/Statistics
# /wiki/Mathematical_software
# /wiki/Information_theory
# /wiki/Mathematical_analysis
# /wiki/Numerical_analysis
# /wiki/Theoretical_computer_science
# /wiki/Information_system
# /wiki/Database
# /wiki/Computer_data_storage
# /wiki/Enterprise_information_system
# /wiki/Social_software
# /wiki/Geographic_information_system
# /wiki/Decision_support_system
# /wiki/Process_control
# /wiki/Multimedia_database
# /wiki/Data_mining
# /wiki/Digital_library
# /wiki/Computing_platform
# /wiki/Digital_marketing
# /wiki/World_Wide_Web
# /wiki/Information_retrieval
# /wiki/Computer_security
# /wiki/Cryptography
# /wiki/Formal_methods
# /wiki/Security_service_(telecommunication)
# /wiki/Intrusion_detection_system
# /wiki/Computer_security_compromised_by_hardware_failure
# /wiki/Network_security
# /wiki/Information_security
# /wiki/Application_security
# /wiki/Human%E2%80%93computer_interaction
# /wiki/Interaction_design
# /wiki/Social_computing
# /wiki/Ubiquitous_computing
# /wiki/Visualization_(graphics)
# /wiki/Computer_accessibility
# /wiki/Synthography
# /wiki/Concurrency_(computer_science)
# /wiki/Concurrent_computing
# /wiki/Parallel_computing
# /wiki/Distributed_computing
# /wiki/Multithreading_(computer_architecture)
# /wiki/Multiprocessing
# /wiki/Artificial_intelligence
# /wiki/Natural_language_processing
# /wiki/Knowledge_representation_and_reasoning
# /wiki/Computer_vision
# /wiki/Automated_planning_and_scheduling
# /wiki/Mathematical_optimization
# /wiki/Control_theory
# /wiki/Philosophy_of_artificial_intelligence
# /wiki/Distributed_artificial_intelligence
# /wiki/Machine_learning
# /wiki/Supervised_learning
# /wiki/Unsupervised_learning
# /wiki/Reinforcement_learning
# /wiki/Multi-task_learning
# /wiki/Cross-validation_(statistics)
# /wiki/Computer_graphics
# /wiki/Computer_animation
# /wiki/Rendering_(computer_graphics)
# /wiki/Photograph_manipulation
# /wiki/Graphics_processing_unit
# /wiki/Mixed_reality
# /wiki/Virtual_reality
# /wiki/Image_compression
# /wiki/Solid_modeling
# /wiki/Enterprise_software
# /wiki/Computational_mathematics
# /wiki/Computational_physics
# /wiki/Computational_chemistry
# /wiki/Computational_biology
# /wiki/Computational_social_science
# /wiki/Computational_engineering
# /wiki/Health_informatics
# /wiki/Digital_art
# /wiki/Electronic_publishing
# /wiki/Cyberwarfare
# /wiki/Electronic_voting
# /wiki/Video_game
# /wiki/Word_processor
# /wiki/Operations_research
# /wiki/Educational_technology
# /wiki/Document_management_system
# /wiki/Category:Computer_science
# /wiki/Outline_of_computer_science
# /wiki/Wikipedia:WikiProject_Computer_science
# https://commons.wikimedia.org/wiki/Category:Computer_science
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q484847#identifiers
# https://catalogue.bnf.fr/ark:/12148/cb12532009h
# https://data.bnf.fr/ark:/12148/cb12532009h
# https://d-nb.info/gnd/4592128-3
# http://uli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007561259505171
# https://id.loc.gov/authorities/sh96008434
# https://id.ndl.go.jp/auth/ndlna/00577580
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=ph119896&CON_LNG=ENG
# https://en.wikipedia.org/w/index.php?title=E-commerce&oldid=1159475624
# /wiki/Help:Category
# /wiki/Category:E-commerce
# /wiki/Category:Electronics_industry
# /wiki/Category:Non-store_retailing
# /wiki/Category:Retail_formats
# /wiki/Category:Supply_chain_management
# /wiki/Category:Pages_with_non-numeric_formatnum_arguments
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Use_dmy_dates_from_January_2022
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_October_2015
# /wiki/Category:Articles_with_unsourced_statements_from_March_2019
# /wiki/Category:Pages_using_div_col_with_small_parameter
# /wiki/Category:CS1_maint:_url-status
# /wiki/Category:Pages_using_Sister_project_links_with_default_search
# /wiki/Category:Pages_using_Sister_project_links_with_wikidata_mismatch
# /wiki/Category:Pages_using_Sister_project_links_with_hidden_wikidata
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_BNFdata_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_NDL_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# https://creativecommons.org/licenses/by-sa/4.0/
# //creativecommons.org/licenses/by-sa/4.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=E-commerce&mobileaction=toggle_view_mobile
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# Program 4
#
# b. Retrieving All Titles from a Wikipedia Webpage:

# %%
import requests
from bs4 import BeautifulSoup

def retrieve_titles_from_wikipedia(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    titles = []

    for link in soup.find_all('a'):
        title = link.text
        if title:
            titles.append(title)

    return titles

# Example usage
wikipedia_url = 'https://en.wikipedia.org/wiki/Social_media_analytics'
titles = retrieve_titles_from_wikipedia(wikipedia_url)
for title in titles:
    print(title)
# Out:
# Jump to content
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Donate
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
#
#
#
#
#
#
#
#
# Search
#
# Create account
# Log in
#  Create account
#  Log in
# learn more
# Contributions
# Talk
#
# (Top)
#
#
#
# 1Process
#
#
#
# 1.1Data identification
#
#
#
# 1.2Data analysis
#
#
#
# 1.3Information interpretation
#
#
#
# 2Techniques
#
#
#
# 3Impacts on business intelligence
#
#
#
# 4Role in international politics
#
#
#
# 4.12016 United States Presidential Election
#
#
#
# 4.22020 United States Presidential Election Controversies
#
#
#
# 4.3Brexit
#
#
#
# 5See also
#
#
#
# 6References
#
# Afrikaans
# العربية
# Euskara
# فارسی
# 한국어
# עברית
# Magyar
# Norsk bokmål
# Polski
# Português
# Русский
# کوردی
# Српски / srpski
# Suomi
# Edit links
# Article
# Talk
# Read
# Edit
# View history
# Read
# Edit
# View history
# What links here
# Related changes
# Upload file
# Special pages
# Permanent link
# Page information
# Cite this page
# Wikidata item
# Download as PDF
# Printable version
# social network analysis
# improve it
# talk page
# Learn how and when to remove these template messages
# verification
# improve this article
# adding citations to reliable sources
# "Social media analytics"
# news
# newspapers
# books
# scholar
# JSTOR
# Learn how and when to remove this template message
# citation
# footnoting
# Learn how and when to remove this template message
# Learn how and when to remove this template message
# social networks
# Facebook
# Instagram
# LinkedIn
# Twitter
# [1]
# edit
# data analysis
# [2]
# edit
# subsets
# wisdom
# [2]
# Structure
# Structured data
# repository
# database
# unstructured data
# [3]
# Language
# Region
# India
# India
# Photos
# Social media
# Facebook
# Twitter
# Ownership
# copyright
# [4]
# edit
# Data analysis
# business value
# sentiment
# demographics
# [2]
# data model
# computer program
# computer
# word cloud
# [2]
# descriptive statistics
# streaming data
# politician
# debate
# social business
# CPU
# data sets
# CPU
# [2]
# Twitter
# Facebook
# LinkedIn
# enterprise social network
# [5]
# Velocity
# Dimensions
# population
# analytical tool
# system
# [2]
# edit
# Visualization (graphics)
# [6]
# patterns
# audience
# visualization
# [7]
# [7]
# Tell a story
# Storytelling
# Visualization
# [7]
# information visualization
# edit
# Social network analysis
# Natural language processing
# complex event processing
# clustering
# data mining
# correlations
# edit
# business intelligence
# [8]
# [9]
# [10]
# [11]
# [12]
# data breaches
# [13]
# [14]
# [15]
# edit
# original research
# improve it
# verifying
# inline citations
# Learn how and when to remove this template message
# social media mining
# Cambridge Analytica
# 2016 United States presidential election
# Brexit
# data privacy
# edit
# scandal
# [16]
# [17]
# [18]
# edit
# attempts to overturn the 2020 United States presidential election
# 2021 United States Capitol attack
# [19]
# [20]
# edit
# cite
# sources
# improve this section
# adding citations to reliable sources
# removed
# Learn how and when to remove this template message
# Brexit referendum
# 2016 EU referendum
# [21]
# [22]
# [21]
# AIQ
# [23]
# [24]
# [25]
# [26]
# [27]
# edit
# Social media measurement
# Sentiment analysis
# Ambient awareness
# Data mining
# Social media mining
# Social media intelligence
# Social network analysis
# edit
# ^
# ISBN
# 9781138190672
# OCLC
# 975370877
# a
# b
# c
# d
# e
# f
# ISBN
# 978-0-13-389256-7
# ^
# "What is structured data? - Definition from WhatIs.com"
# ^
# ISBN
# 978-0-13-389256-7
# ^
# "Enterprise Social Networks Explained"
# ^
# "Why data visualization matters"
# a
# b
# c
# "The Three Elements of Successful Data Visualizations"
# ^
# "Social Media Analytics as a Business Intelligence Practice:Current Landscape & Future Prospects"
# doi
# 10.5171/2014.920553
# S2CID
# 167544401
# ^
# ^
# ^
# ^
# "Social Media Analytics and Its Applications in Marketing"
# doi
# 10.1561/1700000073
# ISSN
# 1555-0753
# S2CID
# 247201448
# ^
# "Fake It Till You Make It: Reputation, Competition, and Yelp Review Fraud"
# doi
# 10.1287/mnsc.2015.2304
# ISSN
# 0025-1909
# ^
# "Estimating deception in consumer reviews based on extreme terms: Comparison analysis of open vs. closed hotel reservation platforms"
# doi
# 10.1016/j.jbusres.2019.05.016
# ISSN
# 0148-2963
# S2CID
# 181482746
# ^
# "Framework for Social Media Analytics based on Multi-Criteria Decision Making (MCDM) model"
# doi
# 10.1007/s11042-019-7470-2
# ISSN
# 1573-7721
# ^
# doi
# 10.1109/MC.2018.3191268
# S2CID
# 52047339
# ^
# "What can we learn from the Facebook—Cambridge Analytica scandal?"
# doi
# 10.1111/j.1740-9713.2018.01139.x
# ^
# doi
# 10.1002/sres.2644
# S2CID
# 210550036
# ^
# Defense One website
# ^
# Washington Post website
# a
# b
# "Cambridge Analytica 'not involved' in Brexit referendum, says watchdog"
# ^
# "Cambridge Analytica did not misuse data in EU referendum, says watchdog"
# ^
# "AggregateIQ Created Cambridge Analytica's Election Software, and Here's the Proof"
# ^
# "Investigation into the use of data analytics in political campaigns"
# cite journal
# help
# ^
# "Facebook suspends Canadian firm AggregateIQ over data scandal"
# ^
# "Data firm broke Canadian privacy laws with involvement in Brexit, U.S. campaigns - probe"
# ^
# "Results and turnout at the EU referendum"
# https://en.wikipedia.org/w/index.php?title=Social_media_analytics&oldid=1150636733
# Categories
# Social media management
# Social information processing
# Mass media monitoring
# Types of analytics
# CS1 errors: missing periodical
# Articles with short description
# Short description is different from Wikidata
# Articles needing additional references from February 2015
# All articles needing additional references
# Wikipedia references cleanup from February 2015
# All articles needing references cleanup
# Articles covered by WikiProject Wikify from February 2015
# All articles covered by WikiProject Wikify
# Articles with multiple maintenance issues
# Articles that may contain original research from September 2019
# All articles that may contain original research
# Articles needing additional references from September 2019
# Creative Commons Attribution-ShareAlike License 4.0
# Terms of Use
# Privacy Policy
# Wikimedia Foundation, Inc.
# Privacy policy
# About Wikipedia
# Disclaimers
# Contact Wikipedia
# Mobile view
# Developers
# Statistics
# Cookie statement

# %% [markdown]
# Program 5
#
# Auto Search StackOverflow for Errors in Code using Python

# %%
# Import dependencies
from subprocess import Popen, PIPE
import requests
import webbrowser

# We are going to write code to read and run python
# file, and store its output or error.
def execute_return(cmd):
    args = cmd.split()
    proc = Popen(args, stdout=PIPE, stderr=PIPE)
    out, err = proc.communicate()
    return out, err

# This function will make an HTTP request using StackOverflow
# API and the error we get from the 1st function and finally
# returns the JSON file.
def mak_req(error):
    resp = requests.get("https://api.stackexchange.com/" +
                        "/2.2/search?order=desc&tagged=python&sort=activity&intitle={}&site=stackoverflow".format(error))
    return resp.json()

# This function takes the JSON from the 2nd function, and
# fetches and stores the URLs of those solutions which are
# marked as "answered" by StackOverflow. And then finally
# open up the tabs containing answers from StackOverflow on
# the browser.
def get_urls(json_dict):
    url_list = []
    count = 0

    for i in json_dict['items']:
        if i['is_answered']:
            url_list.append(i["link"])
        count += 1
        if count == 3 or count == len(i):
            break

    for i in url_list:
        webbrowser.open(i)


# Below line will go through the provided python file
# And stores the output and error.
out, err = execute_return("python /content/brr.py")


# This line is used to store that part of error we are interested in.
error = err.decode("utf-8").strip().split("\r\n")[-1]
print(error)


# A simple if condition, if error is found then execute 2nd and
# 3rd function, otherwise print "No error".
if error:
    filter_error = error.split(":")
    json1 = mak_req(filter_error[0])
    json2 = mak_req(filter_error[1])
    json = mak_req(error)
    get_urls(json1)
    get_urls(json2)
    get_urls(json)

else:
    print("No error")
# Out:
# Traceback (most recent call last):
#   File "/content/brr.py", line 2, in <module>
#     print (a)
# NameError: name 'a' is not defined

# %% [markdown]
# Program 6
#
# Install Pytrends and do the following tasks:
#
#  Connect to Google
#
#  Build Payload
#
#  Interest Over Time
#
#  Historical Hourly Interest
#
#  Interest by Region
#
#  Top Charts
#
#  Related Queries
#
#  Keyword Suggestion

# %%
# !pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.10/dist-packages (from pytrends) (2.27.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from pytrends) (1.5.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pytrends) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2

# %%
from pytrends.request import TrendReq

# Connect to Google
pytrends = TrendReq(hl='en-US', tz=360)

# Build Payload
keyword = 'Python programming'
pytrends.build_payload(kw_list=[keyword])

# Interest Over Time
interest_over_time = pytrends.interest_over_time()

# Interest by Region
interest_by_region = pytrends.interest_by_region()

# Top Charts
top_charts = pytrends.trending_searches(pn='united_states')

# Related Queries
related_queries = pytrends.related_queries()

# Keyword Suggestion
keyword_suggestions = pytrends.suggestions(keyword)

# Print the results
print("Interest Over Time:")
print(interest_over_time)

print("\nInterest by Region:")
print(interest_by_region)

print("\nTop Charts:")
print(top_charts)

print("\nRelated Queries:")
print(related_queries)

print("\nKeyword Suggestions:")
print(keyword_suggestions)
# Out:
# Interest Over Time:
#             Python programming  isPartial
# date
# 2018-06-17                  52      False
# 2018-06-24                  54      False
# 2018-07-01                  47      False
# 2018-07-08                  52      False
# 2018-07-15                  50      False
# ...                        ...        ...
# 2023-05-07                  72      False
# 2023-05-14                  71      False
# 2023-05-21                  71      False
# 2023-05-28                  67      False
# 2023-06-04                  71       True
#
# [260 rows x 2 columns]
#
# Interest by Region:
#                 Python programming
# geoName
# Afghanistan                      0
# Albania                          0
# Algeria                          7
# American Samoa                   0
# Andorra                          0
# ...                            ...
# Western Sahara                   0
# Yemen                            0
# Zambia                           0
# Zimbabwe                       100
# Åland Islands                    0
#
# [250 rows x 1 columns]
#
# Top Charts:
#                                0
# 0                  Ted Kaczynski
# 1                   Amanda Nunes
# 2                 Belmont Stakes
# 3                   Le Mans 2023
# 4                 Conor McGregor
# 5              MÉXICO -- Camerún
# 6                   Jimmy Butler
# 7                    Iga Swiatek
# 8                      Las Vegas
# 9                 Beneil Dariush
# 10               Brittney Griner
# 11                       Belmont
# 12                   Amber Alert
# 13                 Vegas Knights
# 14  Teofimo Lopez vs Josh Taylor
# 15                  Garth Brooks
# 16           Dodgers vs Phillies
# 17                Erling Haaland
# 18                           NBA
# 19              Champions League
#
# Related Queries:
# {'Python programming': {'top':                                   query  value
# 0                 programming in python    100
# 1                       python language     62
# 2                  programming language     61
# 3           python programming language     59
# 4                                  what     46
# 5            what is python programming     38
# 6                   what is programming     38
# 7                        what is python     37
# 8               programming with python     30
# 9                python programming pdf     23
# 10                           python pdf     23
# 11                          python code     22
# 12                    learn programming     22
# 13                         learn python     22
# 14              python programming code     21
# 15             learn python programming     20
# 16         python programming languages     19
# 17                programming languages     18
# 18                     java programming     17
# 19                                 java     17
# 20                                which     17
# 21                       python program     16
# 22  what is python programming language     15
# 23              what is python language     14
# 24            online python programming     14, 'rising':                                                 query  value
# 0                                        google colab  13600
# 1       which type of programming does python support  10400
# 2   python is an example of what type of programmi...   9300
# 3      which type of programming does python support?   7650
# 4           certified associate in python programming   1900
# 5                                     what is cpython   1550
# 6           who developed python programming language   1200
# 7                                              replit    900
# 8          who developed python programming language?    850
# 9                                        freecodecamp    600
# 10          core python programming nageswara rao pdf    600
# 11                                           leetcode    600
# 12                                               cs50    500
# 13                                             libgen    450
# 14        what type of programming language is python    450
# 15                                   jupyter notebook    300
# 16       python programming questions and answers pdf    300
# 17                             python online compiler    300
# 18       elements of programming interviews in python    300
# 19                               data types in python    250
# 20                         ai programming with python    250
# 21           python programming questions and answers    250
# 22                                              which    250
# 23                                 visual studio code    250
# 24   elements of programming interviews in python pdf    250}}
#
# Keyword Suggestions:
# [{'mid': '/m/05z1_', 'title': 'Python', 'type': 'Programming language'}, {'mid': '/g/11fmrll9fp', 'title': 'Automate the Boring Stuff with Python: Practical Programming for Total Beginners', 'type': 'Book by Al Al Sweigart'}, {'mid': '/g/11dxqcx7f2', 'title': 'Deep Learning with Python', 'type': 'Book by François Chollet'}, {'mid': '/g/11cm595pqf', 'title': 'Practical Statistics for Data Scientists: 50+ Essential Concepts Using R and Python', 'type': 'Book by Andrew Bruce, Peter Bruce, and Peter Gedeck'}, {'mid': '/g/11q4hc15y4', 'title': 'Python Crash Course, 3rd Edition: A Hands-On, Project-Based Introduction to Programming', 'type': 'Book by Eric Matthes'}]
